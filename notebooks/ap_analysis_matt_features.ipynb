# %% [markdown]
# # AP Analysis Feature Tables (Aggregated)
#
# This notebook assembles the requested feature tables using every newsroom database in `out/to-download/*.db`. Each table mirrors the original AP-only outputs but concatenates rows from AP, BBC, Guardian, Independent, NYTimes, and Washington Post collections so analysts can work with the full combined corpus.

# %% [markdown]
# ## Setup & Helper Utilities
# The helper below discovers all available `*-analysis.db` files, establishes a shared query runner, and appends a `dataset` column (derived from the filename) to every table so downstream users can filter results per newsroom.

# %%
from pathlib import Path
import sqlite3

import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

# Locate every newsroom analysis database
analysis_root = Path('../out/to-download')
db_paths = sorted(analysis_root.glob('*.db'))
assert db_paths, f"No databases found under {analysis_root}"


def remove_suffix(text: str, suffix: str) -> str:
    return text[:-len(suffix)] if suffix and text.endswith(suffix) else text


def dataset_name(db_path: Path) -> str:
    """Return a concise newsroom label derived from the DB filename."""
    return remove_suffix(db_path.stem, '-analysis')


def run_query_across_databases(query: str) -> pd.DataFrame:
    """Execute the SQL query on every database and concatenate the results."""
    frames = []
    for db_path in db_paths:
        print(f'running on {db_path}')
        with sqlite3.connect(db_path) as conn:
            df = pd.read_sql_query(query, conn)
        df['dataset'] = dataset_name(db_path)
        frames.append(df)
    if not frames:
        return pd.DataFrame()
    combined = pd.concat(frames, ignore_index=True, sort=False)
    ordered_cols = ['dataset'] + [col for col in combined.columns if col != 'dataset']
    return combined[ordered_cols]

print('Using analysis databases:')
for path in db_paths:
    print(f"- {dataset_name(path)} -> {path}")
# Out:
# Using analysis databases:
# - ap -> ../out/to-download/ap-analysis.db
# - bbc -> ../out/to-download/bbc-analysis.db
# - guardian -> ../out/to-download/guardian-analysis.db
# - independent -> ../out/to-download/independent-analysis.db
# - nytimes -> ../out/to-download/nytimes-analysis.db
# - washpo -> ../out/to-download/washpo-analysis.db

# %% [markdown]
# ## Source-level Table
# Each row represents a quoted source mention aggregated across all newsrooms. `source_location` records the character span (`start-end`) of the attribution, while `first_seen`/`last_seen` originate from `sources_agg`.

# %%
source_query = """
WITH source_base AS (
    SELECT
        sm.source_id_within_article AS source_id,
        COALESCE(NULLIF(sm.source_canonical, ''), sm.source_surface) AS source_name,
        sm.char_start,
        sm.char_end,
        v.timestamp_utc AS update_time,
        sm.attributed_text AS body_of_text,
        sm.article_id AS unique_article_id,
        sm.version_id AS update_version_id,
        sa.first_seen_time AS first_seen,
        sa.last_seen_time AS last_seen,
        sm.confidence AS confidence_score
    FROM source_mentions sm
    JOIN versions v ON sm.version_id = v.version_id
    LEFT JOIN sources_agg sa
        ON sm.article_id = sa.article_id
        AND sm.news_org = sa.news_org
        AND sm.source_id_within_article = sa.source_id_within_article
)
SELECT
    source_id,
    source_name,
    printf('%d-%d', char_start, char_end) AS source_location,
    update_time,
    body_of_text,
    unique_article_id,
    update_version_id,
    first_seen,
    last_seen,
    confidence_score
FROM source_base
ORDER BY unique_article_id, update_version_id, source_id
"""

source_df = run_query_across_databases(source_query)
source_df.head()
# Out:
#   dataset source_id     source_name source_location  \
# 0      ap      s001    Barack Obama         362-425
# 1      ap      s001    Barack Obama         362-425
# 2      ap      s001    Barack Obama         362-425
# 3      ap      s001    Barack Obama         362-425
# 4      ap      s002  Neil Eggleston       1244-1460
#
#                   update_time  \
# 0  2017-01-18 15:48:03.845167
# 1  2017-01-18 15:48:03.845167
# 2  2017-01-18 15:48:03.845167
# 3  2017-01-18 15:48:03.845167
# 4  2017-01-18 15:48:03.845167
#
#                                                                                                               body_of_text  \
# 0                                                          Manning will be freed in May, almost 30 years ahead of schedule
# 1                                                          Manning will be freed in May, almost 30 years ahead of schedule
# ...

# %% [markdown]
# ## Entity-level Table
# `entity_location` mirrors the `start-end` character span of each recognised entity. Lifecycle timestamps are derived by grouping mentions within the same article across datasets.

# %%
entity_query = """
WITH entity_base AS (
    SELECT
        em.entity_id_within_article AS entity_id,
        em.entity_type,
        em.canonical_name AS entity_name,
        em.char_start,
        em.char_end,
        v.timestamp_utc AS update_time,
        em.article_id AS unique_article_id,
        em.version_id AS update_version_id
    FROM entity_mentions em
    JOIN versions v ON em.version_id = v.version_id
),
entity_bounds AS (
    SELECT
        entity_id,
        unique_article_id,
        MIN(update_time) AS first_seen,
        MAX(update_time) AS last_seen
    FROM entity_base
    GROUP BY entity_id, unique_article_id
)
SELECT
    eb.entity_id,
    eb.entity_type,
    eb.entity_name,
    printf('%d-%d', eb.char_start, eb.char_end) AS entity_location,
    eb.update_time,
    eb.unique_article_id,
    eb.update_version_id,
    b.first_seen,
    b.last_seen
FROM entity_base eb
JOIN entity_bounds b
  ON eb.entity_id = b.entity_id
 AND eb.unique_article_id = b.unique_article_id
ORDER BY eb.unique_article_id, eb.update_version_id, eb.entity_id
"""

entity_df = run_query_across_databases(entity_query)
entity_df.head()
# Out:
#   dataset entity_id entity_type entity_name entity_location  \
# 0      ap      e001         ORG  washington           12-30
# 1      ap      e001         ORG  washington           12-30
# 2      ap      e001         ORG  washington           12-30
# 3      ap      e001         ORG  washington           12-30
# 4      ap      e002         ORG          ap           31-33
#
#                   update_time  unique_article_id update_version_id  \
# 0  2017-01-18 15:48:03.845167                  1                 1
# 1  2017-01-18 15:48:03.845167                  1                 1
# 2  2017-01-18 15:48:03.845167                  1                 1
# 3  2017-01-18 15:48:03.845167                  1                 1
# 4  2017-01-18 15:48:03.845167                  1                 1
#
#                    first_seen                   last_seen
# 0  2017-01-18 15:48:03.845167  2017-01-18 19:30:03.362584
# 1  2017-01-18 15:48:03.845167  2017-01-18 19:30:03.362584
# ...

# %% [markdown]
# ## Version-level Table
# One row per captured revision, with the sequential number used during ingestion for every newsroom.

# %%
version_query = """
SELECT
    v.version_id AS unique_version_id,
    v.article_id AS unique_article_id,
    v.version_num AS update_version_num,
    v.timestamp_utc AS update_time,
    NULL AS prev_version_id,
    NULL AS prev_version_num,
    NULL AS editor_note,
    v.title AS version_title,
    NULL AS version_summary,
    NULL AS version_body
FROM versions v
ORDER BY v.article_id, v.version_num
"""

version_df = run_query_across_databases(version_query)
version_df.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#   dataset unique_version_id  unique_article_id  update_version_num  \
# 0      ap                 1                  1                   0
# 1      ap                11                  1                   1
# 2      ap               112                  1                   2
# 3      ap                 2                  2                   0
# 4      ap                88                  2                   1
#
#                   update_time prev_version_id prev_version_num editor_note  \
# 0  2017-01-18 15:48:03.845167            None             None        None
# 1  2017-01-18 16:00:03.432431            None             None        None
# ...

# %% [markdown]
# ## Extra Fields
# Additional article-level metadata is available for analysts who need to enrich the requested tables.

# %%
extra_query = """
SELECT
    article_id AS unique_article_id,
    news_org,
    url,
    title_first,
    title_final,
    original_publication_time,
    total_edits,
    is_live_blog
FROM articles
ORDER BY article_id
"""

extra_df = run_query_across_databases(extra_query)
extra_df.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#   dataset  unique_article_id news_org  \
# 0      ap                  1       ap
# 1      ap                  2       ap
# 2      ap                  5       ap
# 3      ap                 10       ap
# 4      ap                 11       ap
#
#                                                                                                          url  \
# 0             http://hosted.ap.org/dynamic/stories/U/US_OBAMA_CLEMENCY?SITE=AP&SECTION=HOME&TEMPLATE=DEFAULT
# 1  http://hosted.ap.org/dynamic/stories/U/US_TRUMP_INAUGURATION_SPEECH?SITE=AP&SECTION=HOME&TEMPLATE=DEFAULT
# 2     http://hosted.ap.org/dynamic/stories/U/US_TRUMP_HEALTH_SECRETARY?SITE=AP&SECTION=HOME&TEMPLATE=DEFAULT
# ...

# %% [markdown]
# ### source-extras
# Additional context captured for each source mention across every newsroom feed.

# %%
source_extras_query = """
SELECT
    sm.source_id_within_article AS source_id,
    sm.article_id AS unique_article_id,
    sm.version_id AS update_version_id,
    sm.source_type,
    sm.speech_style,
    sm.attribution_verb,
    sm.is_in_title,
    sm.is_in_lede,
    sm.is_anonymous,
    sm.anonymous_description,
    sm.anonymous_domain,
    sm.evidence_type,
    sm.evidence_text,
    sm.narrative_function,
    sm.centrality,
    sm.perspective,
    sm.doubted,
    sm.hedge_count,
    sm.hedge_markers,
    sm.epistemic_verbs,
    sm.hedge_stance,
    sm.hedge_confidence,
    sm.prominence_lead_pct
FROM source_mentions sm
ORDER BY sm.article_id, sm.version_id, sm.source_id_within_article
"""

source_extras_df = run_query_across_databases(source_extras_query)
source_extras_df.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#   dataset source_id  unique_article_id update_version_id source_type  \
# 0      ap      s001                  1                 1  government
# 1      ap      s001                  1                 1  government
# 2      ap      s001                  1                 1  government
# 3      ap      s001                  1                 1  government
# 4      ap      s002                  1                 1  government
#
#   speech_style attribution_verb  is_in_title  is_in_lede  is_anonymous  \
# 0     indirect        announced            0           0             0
# 1     indirect        announced            0           0             0
# ...

# %% [markdown]
# ### version-extras
# Per-version analytics and pairwise revision deltas aggregated from every database.

# %%
version_metrics_query = """
SELECT
    vm.version_id,
    vm.article_id AS unique_article_id,
    vm.distinct_sources,
    vm.institutional_share_words,
    vm.anonymous_source_share_words,
    vm.hedge_density_per_1k
FROM version_metrics vm
ORDER BY vm.article_id, vm.version_id
"""

version_metrics_df = run_query_across_databases(version_metrics_query)
version_metrics_df.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#   dataset version_id  unique_article_id  distinct_sources  \
# 0      ap          1                  1                 6
# 1      ap         11                  1                 7
# 2      ap        112                  1                 7
# 3      ap        170                  2                 6
# 4      ap          2                  2                 4
#
#    institutional_share_words  anonymous_source_share_words  \
# 0                   0.845455                      0.209091
# 1                   0.756098                      0.186992
# 2                   0.855932                      0.194915
# 3                   0.000000                      0.000000
# ...

# %%
version_pairs_query = """
SELECT
    vp.article_id AS unique_article_id,
    vp.from_version_id,
    vp.to_version_id,
    vp.from_version_num,
    vp.to_version_num,
    vp.delta_minutes,
    vp.tokens_added,
    vp.tokens_deleted,
    vp.percent_text_new,
    vp.movement_confidence,
    vp.edit_type,
    vp.edit_confidence,
    vp.angle_changed,
    vp.angle_confidence,
    vp.title_jaccard_prev,
    vp.title_jaccard_curr,
    vp.summary_jaccard
FROM version_pairs vp
ORDER BY vp.article_id, vp.from_version_num
"""

version_pairs_df = run_query_across_databases(version_pairs_query)
version_pairs_df.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#   dataset  unique_article_id from_version_id to_version_id  from_version_num  \
# 0      ap                  1               1           112                 0
# 1      ap                  1               1           112                 0
# 2      ap                  1               1           112                 0
# 3      ap                  1               1           112                 0
# 4      ap                  2               2           653                 0
#
#    to_version_num  delta_minutes  tokens_added  tokens_deleted  \
# 0               2     221.991957            71             142
# 1               2     221.991957            71             142
# ...

# %% [markdown]
# ### entity-extras
# No additional entity-level analytics are stored beyond the core fields above; this section remains available for future features such as entity sentiment or co-reference tracking.

# %% [markdown]
# ## Article Date Distribution
# To inspect volume over time, the following cells aggregate `articles.original_publication_time` into daily counts per newsroom and visualize the trend.

# %%
article_dates_query = """
SELECT
    article_id AS unique_article_id,
    original_publication_time
FROM articles
WHERE original_publication_time IS NOT NULL
"""

article_dates_df = run_query_across_databases(article_dates_query)

from datetime import datetime

def parse_iso_datetime(value: str):
    try:
        return datetime.fromisoformat(value)
    except (TypeError, ValueError):
        return None

article_dates_df['original_publication_time'] = article_dates_df['original_publication_time'].map(parse_iso_datetime)
article_dates_df['publication_date'] = article_dates_df['original_publication_time'].map(
    lambda dt: dt.date() if dt is not None else None
)
article_distribution = (
    article_dates_df
    .dropna(subset=['publication_date'])
    .groupby(['dataset', 'publication_date'])
    .size()
    .reset_index(name='article_count')
    .sort_values(['publication_date', 'dataset'])
)

article_distribution.head()
# Out:
# running on ../out/to-download/ap-analysis.db
# running on ../out/to-download/bbc-analysis.db
# running on ../out/to-download/guardian-analysis.db
# running on ../out/to-download/independent-analysis.db
# running on ../out/to-download/nytimes-analysis.db
# running on ../out/to-download/washpo-analysis.db
#     dataset publication_date  article_count
# 465     bbc       2006-08-29              7
# 466     bbc       2006-08-30              4
# 467     bbc       2006-08-31              9
# 468     bbc       2006-09-01              3
# 469     bbc       2006-09-02             15

# %%
appearance_pivot = (
    article_distribution
    .pivot(index='publication_date', columns='dataset', values='article_count')
    .fillna(0)
    .astype(int)
)
appearance_pivot.tail(20)
# Out:
# dataset           ap  bbc  guardian  independent  nytimes  washpo
# publication_date
# 2020-12-14         0    2         0            0        0       0
# 2020-12-15         0    0         1            0        0       0
# 2020-12-16         0    4         0            0        0       0
# 2020-12-17         0    1         3            0        0       0
# 2020-12-21         0    2         2            0        0       0
# 2020-12-22         0    1         0            0        0       0
# 2020-12-23         0    1         0            0        0       0
# 2020-12-25         0    1         2            0        0       0
# 2020-12-26         0    1         0            0        0       0
# 2020-12-29         0    1         0            0        0       0
# 2020-12-30         0    1         0            0        0       0
# 2020-12-31         0    1         0            0        0       0
# 2021-01-03         0    1         0            0        0       0
# ...

# %%
appearance_pivot.sum()
# Out:
# dataset
# ap              7613
# bbc            20089
# guardian        2342
# independent      665
# nytimes          994
# washpo           290
# dtype: int64

# %%
if not appearance_pivot.empty:
    ax = appearance_pivot.plot(kind='line', figsize=(12, 5))
    ax.set_title('Article distribution by publication date')
    ax.set_xlabel('Publication date')
    ax.set_ylabel('Article count')
    plt.tight_layout()
else:
    print('No article publication dates available to plot.')
